# %%
import numpy as np
import matplotlib.pyplot as plt
import rasterio
import xarray
import firedrake
from firedrake import inner, grad, dx, ds, max_value, sqrt, exp, Constant
import icepack
from icepack.constants import (
    ice_density as ρ_I,
    water_density as ρ_W,
    gravity as g,
    weertman_sliding_law as m,
)
import modelfunc

# %% [markdown]
# ### Initial setup
#
# Read in the mesh.

# %%
mesh = firedrake.Mesh("DenmanThermalMesh.msh")
Q = firedrake.FunctionSpace(mesh, "CG", 1)
V = firedrake.VectorFunctionSpace(mesh, "CG", 1)

# %%
fig, ax = plt.subplots()
ax.set_aspect("equal")
firedrake.triplot(mesh, axes=ax)
ax.legend(loc="upper right");

# %% [markdown]
# Read in the velocity data.

# %%
measures_filename = icepack.datasets.fetch_measures_antarctica()
measures = xarray.open_dataset(measures_filename)

# %%
u_obs = icepack.interpolate((measures["VX"], measures["VY"]), V)

# %% [markdown]
# There are some missing points, so just mask them out with 0.
# **TODO**: Fix this awfulness.

# %%
u_obs.dat.data[np.isnan(u_obs.dat.data_ro)] = 0

# %%
fig, ax = plt.subplots()
ax.set_aspect("equal")
colors = firedrake.tripcolor(u_obs, axes=ax)
fig.colorbar(colors);

# %% [markdown]
# Read in the bed, thickness, and surface elevation data.

# %%
bedmachine_filename = icepack.datasets.fetch_bedmachine_antarctica()
bedmachine = xarray.open_dataset(bedmachine_filename)

# %%
b = icepack.interpolate(bedmachine["bed"], Q)
h_obs = icepack.interpolate(bedmachine["thickness"], Q)
h_min = firedrake.Constant(10.0)
h = firedrake.Function(Q).interpolate(max_value(h_min, h_obs))

# %%
s = firedrake.Function(Q).interpolate(max_value(b + h, (1 - ρ_I / ρ_W) * h))

# %% [markdown]
# Plot where the ice appears to be floating or not.

# %%
δh = firedrake.Function(Q).interpolate(s - (1 - ρ_I / ρ_W) * h)

# %%
fig, ax = plt.subplots()
ax.set_aspect("equal")
colors = firedrake.tripcolor(h, axes=ax)
fig.colorbar(colors);

# %%
fig, ax = plt.subplots()
ax.set_aspect("equal")
colors = firedrake.tripcolor(δh, vmin=0.0, vmax=200.0, axes=ax)
fig.colorbar(colors);

# %% [markdown]
# Fetch the ALBMAP data set for other variables (see [here](https://doi.pangaea.de/10.1594/PANGAEA.734145)).
# The last method call below replaces the coordinate names in the original data set (`"x1"`, `"y1"`) with the coordinate names that the icepack interpolation routines are expecting.
# The variable `ghffm` refers to a geothermal heat flux estimate from Fox Maule and others (2005), and `ghfsr` an estimate from Shapiro and Ritzwoller (2004).
# We also need the surface temperature and accumulation.

# %%
# !wget --no-clobber https://store.pangaea.de/Publications/LeBrocq_et_al_2010/ALBMAPv1.nc.zip
# !unzip -n ALBMAPv1.nc.zip
# Out:
# /bin/sh: 1: wget: not found
# /bin/sh: 1: unzip: not found

# %%
albmap = xarray.open_dataset("ALBMAPv1.nc").rename({"x1": "x", "y1": "y"})
[var for var in albmap.data_vars]
# Out:
# ['topg',
#  'lsrf',
#  'usrf',
#  'mask',
#  'firn',
#  'temp',
#  'accr',
#  'acca',
#  'ghffm',
#  'ghfsr',
#  'mask_plus',
#  'glmask',
#  'bmask',
#  'umask',
#  'topg2',
#  'lsrf2']

# %%
T_surface = icepack.interpolate(albmap["temp"], Q)
a = icepack.interpolate(albmap["acca"], Q)

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, sharex=True, sharey=True)
for ax in axes:
    ax.set_aspect("equal")
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

colors = firedrake.tripcolor(T_surface, axes=axes[0])
fig.colorbar(colors, ax=axes[0], orientation="horizontal", pad=0.025, label="surface temperature (C)")
colors = firedrake.tripcolor(a, axes=axes[1])
fig.colorbar(colors, ax=axes[1], orientation="horizontal", pad=0.025, label="accumulation (m / yr)");

# %% [markdown]
# Compute and plot the driving stress but with a smoothing kernel.

# %%
α = firedrake.Constant(10e3)
τ_obs = -ρ_I * g * h * grad(s)
τ_d = firedrake.Function(V)
J = 0.5 * (inner(τ_d - τ_obs, τ_d - τ_obs) + α**2 * inner(grad(τ_d), grad(τ_d))) * dx
F = firedrake.derivative(J, τ_d)
firedrake.solve(F == 0, τ_d)

# %%
fig, ax = plt.subplots()
ax.set_aspect("equal")
colors = firedrake.tripcolor(τ_d, axes=ax)
fig.colorbar(colors);

# %% [markdown]
# Next we need to make an initial guess for the basal shear stress.
# In the interior, we assume that the bed takes up almost all the driving stress.
# Where the ice is close to floating, the bed takes up almost none of the driving stress.

# %%
δh_c = firedrake.Constant(50.0)
f_interior = firedrake.Constant(0.95)
f = firedrake.conditional(
    δh >= δh_c,
    f_interior,
    0.05,
)

# %%
τ_initial = f * sqrt(inner(τ_d, τ_d))
u_min = firedrake.Constant(10.0)
U = max_value(u_min, sqrt(inner(u_obs, u_obs)))
expr = τ_initial / U ** (1 / m)
C_0 = firedrake.Function(Q).interpolate(expr)

# %%
stress = firedrake.sqrt(firedrake.inner(τ_d, τ_d))
print('stress', firedrake.assemble(stress * firedrake.dx))
fraction = firedrake.Constant(0.95)
U = max_value(speed, 1)
C = fraction * stress / U**(1/m)
mExp = 1/m + 1
U0 = firedrake.Constant(300)
C = C * (m/(m+1)) * (U0**mExp + U**mExp)**(1/(m+1))
beta = firedrake.interpolate(firedrake.sqrt(C) * grounded, Q)
# Out:
# stress 18802445543.422813
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[77], line 4
#       2 print('stress', firedrake.assemble(stress * firedrake.dx))
#       3 fraction = firedrake.Constant(0.95)
# ----> 4 U = max_value(speed, 1)
#       5 C = fraction * stress / U**(1/m)
#       6 mExp = 1/m + 1
#
# NameError: name 'speed' is not defined

# %%
fig, ax = plt.subplots()
ax.set_aspect("equal")
colors = firedrake.tripcolor(C_0, axes=ax)
fig.colorbar(colors);

# %% [markdown]
# Initial solve for the ice velocity.

# %%
from icepack.models.viscosity import viscosity_depth_averaged

u_0 = Constant(25.0)
def friction(**kwargs):
    u, ϕ = map(kwargs.get, ("velocity", "log_friction"))
    return m / (m + 1) * C_0 * exp(ϕ) * sqrt(inner(u, u) + u_0**2) ** (1 / m + 1)

T = firedrake.Function(Q).interpolate(T_surface + 273.15)
A_0 = icepack.rate_factor(T)
def viscosity(**kwargs):
    u, h, ψ = map(kwargs.get, ("velocity", "thickness", "log_fluidity"))
    A = A_0 * exp(ψ)
    return viscosity_depth_averaged(velocity=u, thickness=h, fluidity=A)

model = icepack.models.IceStream(friction=friction, viscosity=viscosity)
opts = {
    "dirichlet_ids": [1],
    "diagnostic_solver_type": "petsc",
    "diagnostic_solver_parameters": {
        #"snes_monitor": None,
        "snes_type": "newtonls",
        "snes_linesearch_type": "cp",
        "ksp_type": "gmres",
        "pc_type": "lu",
        "pc_factor_mat_solver_type": "mumps",
    },
}
solver = icepack.solvers.FlowSolver(model, **opts)

ϕ = firedrake.Function(Q)
ψ = firedrake.Function(Q)
u = solver.diagnostic_solve(
    velocity=u_obs, thickness=h, surface=s, log_friction=ϕ, log_fluidity=ψ
)

# %%
type(friction(velocity=u_obs, log_friction=ϕ ))
type(ϕ)
# Out:
# firedrake.function.Function

# %%
firedrake.assemble(ϕ *dx)
# Out:
# 0.0

# %%
fig, ax = plt.subplots()
ax.set_aspect("equal")
colors = firedrake.tripcolor(u, axes=ax)
fig.colorbar(colors);

# %% [markdown]
# ### Friction estimation problem
#
# Now we'll try and back out the friction.
# First we need the error estimates for the velocity.

# %%
σx = icepack.interpolate(measures["ERRX"], Q)
σy = icepack.interpolate(measures["ERRY"], Q)

# %% [markdown]
# There are some patches of missing error estimates, so we'll make them very high there in order to down-weight those velocity values.

# %%
σx.dat.data[np.isnan(σx.dat.data_ro)] = 1000.0
σy.dat.data[np.isnan(σy.dat.data_ro)] = 1000.0

# %%
σ = firedrake.Function(Q).interpolate(sqrt(σx**2 + σy**2))
fig, ax = plt.subplots()
ax.set_aspect("equal")
colors = firedrake.tripcolor(σ, vmax=30.0, axes=ax)
fig.colorbar(colors);

# %% [markdown]
# Solving the inverse problem requires that we:
# 1. Define what simulation is being run
# 2. Create a loss functional, which computes the misfit between the model and data
# 3. Create a regularization functional, which penalizes unphysical behavior in the solution

# %%
def friction_simulation(ϕ):
    return solver.diagnostic_solve(
        velocity=u_obs,
        thickness=h,
        surface=s,
        log_fluidity=ψ,
        log_friction=ϕ,
    )

# %%
area = firedrake.assemble(Constant(1.0) * dx(mesh))
Ω = Constant(area)

# %%
def loss_functional(u):
    δu = u - u_obs
    return 0.5 / Ω * ((δu[0] / σx)**2 + (δu[1] / σy)**2) * dx

α = Constant(5e3)
def friction_regularization(ϕ):
    return 0.5 / Ω * α**2 * inner(grad(ϕ), grad(ϕ)) * dx

# %% [markdown]
# Set up the estimation problem and solver and compute the optimal log-multiplier for the friction.

# %%
from icepack.statistics import (
    StatisticsProblem,
    MaximumProbabilityEstimator,
)

friction_problem = StatisticsProblem(
    simulation=friction_simulation,
    loss_functional=loss_functional,
    regularization=friction_regularization,
    controls=ϕ,
)

# %%
print(type(friction_simulation), type(loss_functional), type(friction_regularization))
# Out:
# <class 'function'> <class 'function'> <class 'function'>

# %%
firedrake.assemble(loss_functional(u))
# Out:
# 10801.845521933166

# %%
friction_estimator = MaximumProbabilityEstimator(
    friction_problem,
    gradient_tolerance=1e-4,
    step_tolerance=1e-1,
    max_iterations=50,
)
ϕ_opt = friction_estimator.solve()
# Out:
# Truncated CG Trust-Region Solver
#   iter  value          gnorm          snorm          delta          #fval     #grad     tr_flag   iterCG    flagCG
#   0     1.080185e+04   8.292368e-01                  9.063993e+03
#   1     5.981814e+03   3.300781e-01   9.063993e+03   2.265998e+04   3         2         0         2         3
#   2     2.987829e+03   1.103014e-01   2.265998e+04   5.664996e+04   4         3         0         2         3
#   3     2.052592e+03   2.251453e-02   5.664996e+04   5.664996e+04   5         4         0         3         2
#   4     2.052592e+03   2.251453e-02   5.664996e+04   3.540622e+03   6         4         2         3         2
#   5     1.982873e+03   1.826847e-02   3.540622e+03   8.851556e+03   7         5         0         1         3
#   38    3.653079e+02   2.549440e-03   1.228400e+03   3.071000e+03   40        32        0         2         3
#   39    3.612597e+02   4.857569e-03   3.071000e+03   7.677501e+03   41        33        0         2         3
#   40    3.498047e+02   4.673615e-03   7.677501e+03   7.677501e+03   42        34        0         3         3
#   41    3.384488e+02   6.030840e-03   7.677501e+03   1.919375e+04   43        35        0         3         3
#   42    3.384488e+02   6.030840e-03   1.919375e+04   1.199610e+03   44        35        2         3         2
#   43    3.354830e+02   3.320071e-03   1.199610e+03   2.999024e+03   45        36        0         3         2
#   44    3.309464e+02   3.117066e-03   2.999024e+03   2.999024e+03   46        37        0         3         3
#   45    3.269963e+02   4.647917e-03   2.999024e+03   7.497559e+03   47        38        0         3         3
#   46    3.187604e+02   3.629226e-03   7.497559e+03   7.497559e+03   48        39        0         3         3
#   47    3.187604e+02   3.629226e-03   7.497559e+03   4.685975e+02   49        39        2         3         2
#   48    3.173668e+02   2.823406e-03   4.685975e+02   1.171494e+03   50        40        0         1         3
#   49    3.152551e+02   3.820598e-03   1.171494e+03   1.171494e+03   51        41        0         1         3
#   50    3.131394e+02   2.032491e-03   1.171494e+03   2.928734e+03   52        42        0         2         3
# Optimization Terminated with Status: Iteration Limit Exceeded

# %%
fig, ax = plt.subplots(size=(10,10))
ax.set_aspect("equal")
colors = firedrake.tripcolor(ϕ_opt, vmin=-1, vmax=+1, cmap="RdBu", axes=ax)
fig.colorbar(colors);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 fig, ax = plt.subplots(size=(10,10))
#       2 ax.set_aspect("equal")
#       3 colors = firedrake.tripcolor(ϕ_opt, vmin=-1, vmax=+1, cmap="RdBu", axes=ax)
#
# File /home/firedrake/firedrake/lib/python3.12/site-packages/matplotlib/pyplot.py:1775, in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1620 def subplots(
#    1621     nrows: int = 1, ncols: int = 1, *,
#    1622     sharex: bool | Literal["none", "all", "row", "col"] = False,
#    (...)
#    1629     **fig_kw
#    1630 ) -> tuple[Figure, Any]:
#    1631     """
#    1632     Create a figure and a set of subplots.
#    1633
#    (...)
#    1773
#    1774     """
# -> 1775     fig = figure(**fig_kw)
#    1776     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1777                        squeeze=squeeze, subplot_kw=subplot_kw,
#    1778                        gridspec_kw=gridspec_kw, height_ratios=height_ratios,
#    1779                        width_ratios=width_ratios)
#    1780     return fig, axs
#
# File /home/firedrake/firedrake/lib/python3.12/site-packages/matplotlib/pyplot.py:1042, in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#    1032 if len(allnums) == max_open_warning >= 1:
#    1033     _api.warn_external(
#    1034         f"More than {max_open_warning} figures have been opened. "
#    1035         f"Figures created through the pyplot interface "
#    (...)
#    1039         f"Consider using `matplotlib.pyplot.close()`.",
#    1040         RuntimeWarning)
# -> 1042 manager = new_figure_manager(
#    1043     num, figsize=figsize, dpi=dpi,
#    1044     facecolor=facecolor, edgecolor=edgecolor, frameon=frameon,
#    1045     FigureClass=FigureClass, **kwargs)
#    1046 fig = manager.canvas.figure
#    1047 if fig_label:
#
# File /home/firedrake/firedrake/lib/python3.12/site-packages/matplotlib/pyplot.py:552, in new_figure_manager(*args, **kwargs)
#     550 """Create a new figure manager instance."""
#     551 _warn_if_gui_out_of_main_thread()
# --> 552 return _get_backend_mod().new_figure_manager(*args, **kwargs)
#
# File /home/firedrake/firedrake/lib/python3.12/site-packages/matplotlib_inline/backend_inline.py:27, in new_figure_manager(num, FigureClass, *args, **kwargs)
#      21 def new_figure_manager(num, *args, FigureClass=Figure, **kwargs):
#      22     """
#      23     Return a new figure manager for a new figure instance.
#      24
#      25     This function is part of the API expected by Matplotlib backends.
#      26     """
# ---> 27     return new_figure_manager_given_figure(num, FigureClass(*args, **kwargs))
#
# File /home/firedrake/firedrake/lib/python3.12/site-packages/matplotlib/figure.py:2560, in Figure.__init__(self, figsize, dpi, facecolor, edgecolor, linewidth, frameon, subplotpars, tight_layout, constrained_layout, layout, **kwargs)
#    2464 def __init__(self,
#    2465              figsize=None,
#    2466              dpi=None,
#    (...)
#    2476              **kwargs
#    2477              ):
#    2478     """
#    2479     Parameters
#    2480     ----------
#    (...)
#    2558         %(Figure:kwdoc)s
#    2559     """
# -> 2560     super().__init__(**kwargs)
#    2561     self._root_figure = self
#    2562     self._layout_engine = None
#
# File /home/firedrake/firedrake/lib/python3.12/site-packages/matplotlib/figure.py:154, in FigureBase.__init__(self, **kwargs)
#     152 self.stale = True
#     153 self.suppressComposite = None
# --> 154 self.set(**kwargs)
#
# File /home/firedrake/firedrake/lib/python3.12/site-packages/matplotlib/artist.py:146, in Artist.__init_subclass__.<locals>.<lambda>(self, **kwargs)
#     138 if not hasattr(cls.set, '_autogenerated_signature'):
#     139     # Don't overwrite cls.set if the subclass or one of its parents
#     140     # has defined a set method set itself.
#     141     # If there was no explicit definition, cls.set is inherited from
#     142     # the hierarchy of auto-generated set methods, which hold the
#     143     # flag _autogenerated_signature.
#     144     return
# --> 146 cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     147 cls.set.__name__ = "set"
#     148 cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# File /home/firedrake/firedrake/lib/python3.12/site-packages/matplotlib/artist.py:1241, in Artist.set(self, **kwargs)
#    1237 def set(self, **kwargs):
#    1238     # docstring and signature are auto-generated via
#    1239     # Artist._update_set_signature_and_docstring() at the end of the
#    1240     # module.
# -> 1241     return self._internal_update(cbook.normalize_kwargs(kwargs, self))
#
# File /home/firedrake/firedrake/lib/python3.12/site-packages/matplotlib/artist.py:1233, in Artist._internal_update(self, kwargs)
#    1226 def _internal_update(self, kwargs):
#    1227     """
#    1228     Update artist properties without prenormalizing them, but generating
#    1229     errors as if calling `set`.
#    1230
#    1231     The lack of prenormalization is to maintain backcompatibility.
#    1232     """
# -> 1233     return self._update_props(
#    1234         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1235         "{prop_name!r}")
#
# File /home/firedrake/firedrake/lib/python3.12/site-packages/matplotlib/artist.py:1206, in Artist._update_props(self, props, errfmt)
#    1204             func = getattr(self, f"set_{k}", None)
#    1205             if not callable(func):
# -> 1206                 raise AttributeError(
#    1207                     errfmt.format(cls=type(self), prop_name=k),
#    1208                     name=k)
#    1209             ret.append(func(v))
#    1210 if ret:
#
# AttributeError: Figure.set() got an unexpected keyword argument 'size'

# %%
u_opt = friction_simulation(ϕ_opt)

# %%
fig, ax = plt.subplots()
ax.set_aspect("equal")
colors = firedrake.tripcolor(u_opt, axes=ax)
fig.colorbar(colors);

# %% [markdown]
# ### Viscosity estimation problem
#
# Now we'll go through a similar procedure but to back out the fluidity, with the friction fixed.
# Observe that here we're using the optimal solution $\phi_{\text{opt}}$ for the log-friction that we found before.

# %%
def fluidity_simulation(ψ):
    return solver.diagnostic_solve(
        velocity=u_obs,
        thickness=h,
        surface=s,
        log_fluidity=ψ,
        log_friction=ϕ_opt,
    )

# %%
β = Constant(10e3)
#   26    1.460109e+02   7.836761e-04   2.856318e+03   7.140795e+03   28        24        0         2         3
#   27    1.441286e+02   2.499010e-04   7.140795e+03   1.785199e+04   29        25        0         2         3
#   28    1.430309e+02   3.954339e-04   1.785199e+04   1.785199e+04   30        26        0         5         3
#   29    1.417382e+02   3.271876e-04   1.785199e+04   1.785199e+04   31        27        0         5         3
#   30    1.406438e+02   3.331723e-04   1.785199e+04   1.785199e+04   32        28        0         5         3
#   31    1.396330e+02   3.792501e-04   1.785199e+04   1.785199e+04   33        29        0         5         3
#   32    1.384264e+02   3.284984e-04   1.785199e+04   1.785199e+04   34        30        0         5         3
#   33    1.371088e+02   2.287446e-04   1.785199e+04   1.785199e+04   35        31        0         5         3
#   34    1.358642e+02   2.769495e-04   1.785199e+04   1.785199e+04   36        32        0         5         3
#   35    1.346870e+02   2.181720e-04   1.785199e+04   4.462997e+04   37        33        0         6         3
#   36    1.331087e+02   5.211999e-04   4.462997e+04   4.462997e+04   38        34        0         6         3
#   37    1.331087e+02   5.211999e-04   4.462997e+04   2.789373e+03   39        34        2         6         2
#   38    1.322920e+02   5.409342e-04   2.789373e+03   6.973433e+03   40        35        0         1         3
#   39    1.311275e+02   1.805492e-04   6.973433e+03   1.743358e+04   41        36        0         2         3
#   40    1.302261e+02   2.067123e-04   1.743358e+04   1.743358e+04   42        37        0         5         3
#   41    1.297084e+02   3.177867e-04   1.743358e+04   1.743358e+04   43        38        0         5         3
#   42    1.292517e+02   5.308499e-04   1.743358e+04   1.743358e+04   44        39        0         5         3
#   43    1.278814e+02   2.013776e-04   1.743358e+04   1.743358e+04   45        40        0         5         3
#   44    1.268033e+02   1.714798e-04   1.743358e+04   1.743358e+04   46        41        0         5         3
#   45    1.258754e+02   1.846613e-04   1.743358e+04   1.743358e+04   47        42        0         6         3
#   46    1.250000e+02   2.292399e-04   1.743358e+04   1.743358e+04   48        43        0         5         3
#   47    1.244098e+02   3.565994e-04   1.743358e+04   1.743358e+04   49        44        0         6         3
#   48    1.236954e+02   3.432331e-04   1.743358e+04   1.743358e+04   50        45        0         5         3
#   49    1.231178e+02   3.873370e-04   1.743358e+04   1.743358e+04   51        46        0         5         3
#   50    1.223604e+02   2.950603e-04   1.743358e+04   1.743358e+04   52        47        0         5         3
# Optimization Terminated with Status: Iteration Limit Exceeded

# %%
fig, ax = plt.subplots()
ax.set_aspect("equal")
colors = firedrake.tripcolor(ψ_opt, vmin=-5, vmax=+5, cmap="RdBu", axes=ax)
fig.colorbar(colors);

# %%
u_opt = fluidity_simulation(ψ_opt)

# %%
fig, ax = plt.subplots()
ax.set_aspect("equal")
colors = firedrake.tripcolor(u_opt, axes=ax)
fig.colorbar(colors);

# %% [markdown]
# ### Porque no los dos
#
# Now let's try to estimate both simultaneously.

# %%
def joint_simulation(controls):
    ϕ, ψ = controls
    return solver.diagnostic_solve(
        velocity=u_obs,
        thickness=h,
        surface=s,
        log_fluidity=ψ,
        log_friction=ϕ,
    )

# %%
def joint_regularization(controls):
    ϕ, ψ = controls
    return 0.5 / Ω * (
        α**2 * inner(grad(ϕ), grad(ϕ)) + β**2 * inner(grad(ψ), grad(ψ))
    ) * dx

# %%
joint_problem = StatisticsProblem(
    simulation=joint_simulation,
    loss_functional=loss_functional,
    regularization=joint_regularization,
    controls=[ϕ_opt, ψ_opt],
)

# %%
joint_estimator = MaximumProbabilityEstimator(
    joint_problem,
    gradient_tolerance=1e-4,
    step_tolerance=1e-1,
    max_iterations=50,
)

# %%
ϕ_opt, ψ_opt = joint_estimator.solve()
# Out:
# Truncated CG Trust-Region Solver
#   iter  value          gnorm          snorm          delta          #fval     #grad     tr_flag   iterCG    flagCG
#   0     1.233187e+02   1.317748e-03                  2.141617e+02
#   1     1.231775e+02   2.186393e-03   2.141617e+02   5.354042e+02   3         2         0         1         3
#   2     1.225673e+02   1.167182e-03   5.354042e+02   1.338511e+03   4         3         0         2         3
#   3     1.214284e+02   2.204951e-03   1.338511e+03   3.346276e+03   5         4         0         2         3
#   4     1.182106e+02   1.546825e-03   3.346276e+03   8.365691e+03   6         5         0         3         3
#   5     1.129985e+02   4.433501e-03   8.365691e+03   2.091423e+04   7         6         0         4         3
#   6     9.935668e+01   6.266634e-03   2.091423e+04   5.228557e+04   8         7         0         6         3
#   7     9.935668e+01   6.266634e-03   5.228557e+04   3.267848e+03   9         7         2         8         2
#   8     9.461622e+01   1.412533e-03   3.267848e+03   8.169620e+03   10        8         0         5         3
#   9     9.016845e+01   3.239157e-03   8.169620e+03   8.169620e+03   11        9         0         5         3
#   10    8.678721e+01   1.943421e-03   8.169620e+03   8.169620e+03   12        10        0         5         3
#   11    8.646510e+01   3.817772e-03   8.169620e+03   8.169620e+03   13        11        0         5         3
#   12    8.646510e+01   3.817772e-03   8.169620e+03   2.042405e+03   14        11        2         4         2
#   13    8.378033e+01   2.546032e-03   2.042405e+03   2.042405e+03   15        12        0         3         3
#   14    8.361312e+01   4.250082e-03   2.042405e+03   2.042405e+03   16        13        0         3         3
#   15    8.330815e+01   3.232159e-03   2.042405e+03   2.042405e+03   17        14        0         3         3
#   16    8.261012e+01   3.506620e-03   2.042405e+03   2.042405e+03   18        15        0         3         2
#   17    8.203697e+01   2.753394e-03   2.042405e+03   2.042405e+03   19        16        0         4         3
#   18    8.169641e+01   3.996379e-03   2.042405e+03   2.042405e+03   20        17        0         3         2
#   19    8.109421e+01   2.610718e-03   2.042405e+03   2.042405e+03   21        18        0         4         3
#   20    8.109421e+01   2.610718e-03   2.042405e+03   1.276503e+02   22        18        2         3         3
#   21    8.080638e+01   2.153263e-03   1.276503e+02   3.191258e+02   23        19        0         1         3
#   22    8.023903e+01   1.612598e-03   3.191258e+02   7.978145e+02   24        20        0         1         3
#   23    7.968888e+01   1.838050e-03   7.978145e+02   7.978145e+02   25        21        0         2         3
